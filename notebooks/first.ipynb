# %%
# Clone le dépôt et place-toi dans le dossier (à exécuter en premier sur Colab)
# !git clone https://github.com/oussama455/pfa.git
# %cd pfa
# Out:
# Cloning into 'pfa'...
# remote: Enumerating objects: 308, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 308 (delta 43), reused 100 (delta 30), pack-reused 185 (from 1)
# Receiving objects: 100% (308/308), 631.17 MiB | 19.88 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Updating files: 100% (137/137), done.
# /content/pfa

# %%
from notebooks.colab_setup import setup

project_root = setup(
    repo_url="https://github.com/oussama455/pfa.git",
    branch="main",
    install=True,
    use_drive=True,  # recommandé pour les gros fichiers
)
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6879/2892135731.py in <cell line: 0>()
#       1 from notebooks.colab_setup import setup
#       2
# ----> 3 project_root = setup(
#       4     repo_url="https://github.com/<user>/pfa.git",
#       5     branch="main",
#
# /content/pfa/notebooks/colab_setup.py in setup(repo_url, branch, install, use_drive)
#     132             project_root = drive_root / "pfa"
#     133             if not (project_root / "pipeline").exists():
# --> 134                 raise FileNotFoundError(
#     135                     f"{project_root} n'existe pas ou ne contient pas pipeline/. "
#     136                     "Copie le projet sur Drive d'abord."
#
# FileNotFoundError: /content/drive/MyDrive/pfa n'existe pas ou ne contient pas pipeline/. Copie le projet sur Drive d'abord.

# %% [markdown]
# Place tes données dans `/content/drive/MyDrive/pfa/data/` pour qu’elles soient accessibles depuis Colab.

# %% [markdown]
# # Entraînement des datasets dans Google Colab via VS Code
#
# Ce notebook permet de configurer l’environnement Colab, d’accéder à Google Drive, et de lancer l’entraînement de tes modèles (U-Net, Mask2Former) directement depuis VS Code.

# %%
# !python scripts/train_semap.py --epochs 20 --batch-size 8
# Out:
# python3: can't open file '/content/scripts/train_semap.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Pour Mask2Former (option avancée, nécessite plus de VRAM)

# %%
# !pip install -U openmim
# !mim install mmengine "mmcv>=2.0.0,<2.2.0" "mmsegmentation>=1.2.2"
# puis ton script d'entraînement avancé
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 5, in <module>
#     from mim.cli import cli
#   File "/usr/local/lib/python3.12/dist-packages/mim/__init__.py", line 10, in <module>
#     import setuptools  # noqa: F401
#     ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/setuptools/__init__.py", line 16, in <module>
#     import setuptools.version
#   File "/usr/local/lib/python3.12/dist-packages/setuptools/version.py", line 1, in <module>
#     import pkg_resources
#   File "/usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py", line 2172, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
